# %% [markdown]
# # My Jupiter Notebook on IBM Watsaon Studio

# %% [markdown]
# **Pierre T Yesso**<br/>
# Data Scientist

# %% [markdown]
# *I am interested in data science because I am passionate about predictions and decisions made out of collected data.*

# %% [markdown]
# ### Code below is doing basic addition

# %%
1+1
# Out:
# 2

# %% [markdown]
# **_Table_**<br/>
#
# <table class="demo">
# <thead>
#     <tr>
#         <th>First Name</th>
#         <th>Last Name</th>
#     </tr>
#     </thead>
#     <tbody>
#     <tr>
#         <td>John</td>
#         <td>Doe</td>
#     </tr>
#     <tr>
#         <td>Pierre</td>
#         <td>Yesso</td>
#     </tr>
#     </tbody>
# </table>
#
#
# **_Bullet List_**<br/>
#
#  - Bullet 1
#   - Bullet 1.1
#   - Bullet 1.2
#
# **_Hyperlink_**<br/>
# __[My LinkedIn profile](https://www.linkedin.com/in/yessotheo)__
#
# **_Horizontal rule_**<br/>
#
# ***
#
# <p style="font-size:100px">&#128521;</p>
